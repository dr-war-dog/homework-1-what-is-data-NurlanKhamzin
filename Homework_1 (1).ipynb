# %%
## Author: Nurlan Khamzin
## Date: 09/08/2018
## IS 590: Data Visualization
## University of Illinois at Urbana-Champaign

# %%
# Question #1
import pandas as pd
import matplotlib.pyplot as plt
data = pd.DataFrame.from_csv("UIUC-iSchool-DataViz/fall2018/week02/data/la-county-restaurant-inspections.csv")
la_rest_inspect_mean = data['score'].mean()
print("The mean score of the LA County Resturant Inspections: " + str(la_rest_inspect_mean))
## Visualization
plt.hist(data['score'], color='c', edgecolor='k')
plt.axvline(data['score'].mean(), color='r', linestyle='dashed', linewidth=0.5)
plt.show()
## This is continuous data since I used numeric values of 'score' column that varies across the dataset.
# Out:
# The mean score of the LA County Resturant Inspections: 93.75330640483668

# %%
# Question #2
import pandas as pd
import csv
import matplotlib.pyplot as plt
import numpy as np
data = pd.DataFrame.from_csv("UIUC-iSchool-DataViz/fall2018/week02/data/la-county-restaurant-inspections.csv")
restaurant_count = 0
data_csv = open('UIUC-iSchool-DataViz/fall2018/week02/data/la-county-restaurant-inspections.csv')
csv_reader = csv.reader(data_csv)
header = next(csv_reader)
for line in csv_reader:
    address = line[2]
    if address == "17660 CHATSWORTH ST":
        restaurant_count += 1
print 'Facilitiy on 17660 Chatsworth Street was visited', str(restaurant_count), 'times.'
## Visualization
data = pd.DataFrame.from_csv("UIUC-iSchool-DataViz/fall2018/week02/data/la-county-restaurant-inspections.csv")
addresses = np.array(data['facility_address'], dtype='str')
data['facility_address'].value_counts().plot(kind='bar')
## This is categorical data, but may seem to be continuous because adresses are different and varies across the dataset as well.
## However since it has duplicates I used it as a classifier to filter the data.
# Out:
# Facilitiy on 17660 Chatsworth Street was visited 6 times.
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-2-735bfe84bfaf> in <module>()
#      16 data = pd.DataFrame.from_csv("UIUC-iSchool-DataViz/fall2018/week02/data/la-county-restaurant-inspections.csv")
#      17 addresses = np.array(data['facility_address'], dtype='str')
# ---> 18 data['facility_address'].value_counts().plot(kind='bar')
#      19 ## This is categorical data, but may seem to be continuous because adresses are different and varies across the dataset as well.
#      20 ## However since it has duplicates I used it as a classifier to filter the data.
#
# c:\python27\arcgis10.4\lib\site-packages\pandas\tools\plotting.pyc in plot_series(data, kind, ax, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, label, secondary_y, **kwds)
#    2517                  yerr=yerr, xerr=xerr,
#    2518                  label=label, secondary_y=secondary_y,
# -> 2519                  **kwds)
#    2520
#    2521
#
# c:\python27\arcgis10.4\lib\site-packages\pandas\tools\plotting.pyc in _plot(data, x, y, subplots, ax, kind, **kwds)
#    2322         plot_obj = klass(data, subplots=subplots, ax=ax, kind=kind, **kwds)
#    2323
# -> 2324     plot_obj.generate()
#    2325     plot_obj.draw()
#    2326     return plot_obj.result
#
# c:\python27\arcgis10.4\lib\site-packages\pandas\tools\plotting.pyc in generate(self)
#     912         self._compute_plot_data()
#     913         self._setup_subplots()
# --> 914         self._make_plot()
#     915         self._add_table()
#     916         self._make_legend()
#
# c:\python27\arcgis10.4\lib\site-packages\pandas\tools\plotting.pyc in _make_plot(self)
#    1883                 w = self.bar_width / K
#    1884                 rect = bar_f(ax, self.ax_pos + (i + 0.5) * w, y, w,
# -> 1885                              start=start, label=label, **kwds)
#    1886             self._add_legend_handle(rect, label, index=i)
#    1887
#
# c:\python27\arcgis10.4\lib\site-packages\pandas\tools\plotting.pyc in f(ax, x, y, w, start, **kwds)
#    1828             def f(ax, x, y, w, start=None, **kwds):
#    1829                 start = start + self.bottom
# -> 1830                 return ax.bar(x, y, w, bottom=start, log=self.log, **kwds)
#    1831         elif self.kind == 'barh':
#    1832
#
# c:\python27\arcgis10.4\lib\site-packages\matplotlib\__init__.pyc in inner(ax, *args, **kwargs)
#    1865                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1866                         RuntimeWarning, stacklevel=2)
# -> 1867             return func(ax, *args, **kwargs)
#    1868
#    1869         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# c:\python27\arcgis10.4\lib\site-packages\matplotlib\axes\_axes.pyc in bar(self, *args, **kwargs)
#    2289             elif orientation == 'horizontal':
#    2290                 r.sticky_edges.x.append(l)
# -> 2291             self.add_patch(r)
#    2292             patches.append(r)
#    2293
#
# c:\python27\arcgis10.4\lib\site-packages\matplotlib\axes\_base.pyc in add_patch(self, p)
#    2032         self._set_artist_props(p)
#    2033         if p.get_clip_path() is None:
# -> 2034             p.set_clip_path(self.patch)
#    2035         self._update_patch_limits(p)
#    2036         self.patches.append(p)
#
# c:\python27\arcgis10.4\lib\site-packages\matplotlib\artist.pyc in set_clip_path(self, path, transform)
#     671             if isinstance(path, Rectangle):
#     672                 self.clipbox = TransformedBbox(Bbox.unit(),
# --> 673                                                path.get_transform())
#     674                 self._clippath = None
#     675                 success = True
#
# c:\python27\arcgis10.4\lib\site-packages\matplotlib\patches.pyc in get_transform(self)
#     197         to the :class:`Patch`.
#     198         """
# --> 199         return self.get_patch_transform() + artist.Artist.get_transform(self)
#     200
#     201     def get_data_transform(self):
#
# c:\python27\arcgis10.4\lib\site-packages\matplotlib\transforms.pyc in __add__(self, other)
#    1285         """
#    1286         if isinstance(other, Transform):
# -> 1287             return composite_transform_factory(self, other)
#    1288         raise TypeError(
#    1289             "Can not add Transform to object of type '%s'" % type(other))
#
# c:\python27\arcgis10.4\lib\site-packages\matplotlib\transforms.pyc in composite_transform_factory(a, b)
#    2599     elif isinstance(a, Affine2D) and isinstance(b, Affine2D):
#    2600         return CompositeAffine2D(a, b)
# -> 2601     return CompositeGenericTransform(a, b)
#    2602
#    2603
#
# c:\python27\arcgis10.4\lib\site-packages\matplotlib\transforms.pyc in __init__(self, a, b, **kwargs)
#    2413         self._a = a
#    2414         self._b = b
# -> 2415         self.set_children(a, b)
#    2416
#    2417     is_affine = property(lambda self: self._a.is_affine and self._b.is_affine)
#
# c:\python27\arcgis10.4\lib\site-packages\matplotlib\transforms.pyc in set_children(self, *children)
#     178         # keep them alive.
#     179         for child in children:
# --> 180             child._parents[id(self)] = weakref.ref(self)
#     181
#     182     if DEBUG:
#
# MemoryError:
# Error in callback <function post_execute at 0x0F3690F0> (for post_execute):
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# c:\python27\arcgis10.4\lib\site-packages\matplotlib\pyplot.pyc in post_execute()
#     147             def post_execute():
#     148                 if matplotlib.is_interactive():
# --> 149                     draw_all()
#     150
#     151             # IPython >= 2
#
# c:\python27\arcgis10.4\lib\site-packages\matplotlib\_pylab_helpers.pyc in draw_all(cls, force)
#     134         for f_mgr in cls.get_all_fig_managers():
#     135             if force or f_mgr.canvas.figure.stale:
# --> 136                 f_mgr.canvas.draw_idle()
#     137
#     138 atexit.register(Gcf.destroy_all)
#
# c:\python27\arcgis10.4\lib\site-packages\matplotlib\backend_bases.pyc in draw_idle(self, *args, **kwargs)
#    2053         if not self._is_idle_drawing:
#    2054             with self._idle_draw_cntx():
# -> 2055                 self.draw(*args, **kwargs)
#    2056
#    2057     def draw_cursor(self, event):
#
# c:\python27\arcgis10.4\lib\site-packages\matplotlib\backends\backend_agg.pyc in draw(self)
#     427         Draw the figure using the renderer
#     428         """
# --> 429         self.renderer = self.get_renderer(cleared=True)
#     430         # acquire a lock on the shared font cache
#     431         RendererAgg.lock.acquire()
#
# c:\python27\arcgis10.4\lib\site-packages\matplotlib\backends\backend_agg.pyc in get_renderer(self, cleared)
#     452
#     453         if need_new_renderer:
# --> 454             self.renderer = RendererAgg(w, h, self.figure.dpi)
#     455             self._lastKey = key
#     456         elif cleared:
#
# c:\python27\arcgis10.4\lib\site-packages\matplotlib\backends\backend_agg.pyc in __init__(self, width, height, dpi)
#      99         self.width = width
#     100         self.height = height
# --> 101         self._renderer = _RendererAgg(int(width), int(height), dpi)
#     102         self._filter_renderers = []
#     103
#
# MemoryError: In RendererAgg: Out of memory
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# c:\python27\arcgis10.4\lib\site-packages\IPython\core\formatters.pyc in __call__(self, obj)
#     332                 pass
#     333             else:
# --> 334                 return printer(obj)
#     335             # Finally look for special method names
#     336             method = get_real_method(obj, self.print_method)
#
# c:\python27\arcgis10.4\lib\site-packages\IPython\core\pylabtools.pyc in <lambda>(fig)
#     245
#     246     if 'png' in formats:
# --> 247         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     248     if 'retina' in formats or 'png2x' in formats:
#     249         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# c:\python27\arcgis10.4\lib\site-packages\IPython\core\pylabtools.pyc in print_figure(fig, fmt, bbox_inches, **kwargs)
#     129
#     130     bytes_io = BytesIO()
# --> 131     fig.canvas.print_figure(bytes_io, **kw)
#     132     data = bytes_io.getvalue()
#     133     if fmt == 'svg':
#
# c:\python27\arcgis10.4\lib\site-packages\matplotlib\backend_bases.pyc in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2210                     orientation=orientation,
#    2211                     dryrun=True,
# -> 2212                     **kwargs)
#    2213                 renderer = self.figure._cachedRenderer
#    2214                 bbox_inches = self.figure.get_tightbbox(renderer)
#
# c:\python27\arcgis10.4\lib\site-packages\matplotlib\backends\backend_agg.pyc in print_png(self, filename_or_obj, *args, **kwargs)
#     515
#     516     def print_png(self, filename_or_obj, *args, **kwargs):
# --> 517         FigureCanvasAgg.draw(self)
#     518         renderer = self.get_renderer()
#     519         original_dpi = renderer.dpi
#
# c:\python27\arcgis10.4\lib\site-packages\matplotlib\backends\backend_agg.pyc in draw(self)
#     427         Draw the figure using the renderer
#     428         """
# --> 429         self.renderer = self.get_renderer(cleared=True)
#     430         # acquire a lock on the shared font cache
#     431         RendererAgg.lock.acquire()
#
# c:\python27\arcgis10.4\lib\site-packages\matplotlib\backends\backend_agg.pyc in get_renderer(self, cleared)
#     452
#     453         if need_new_renderer:
# --> 454             self.renderer = RendererAgg(w, h, self.figure.dpi)
#     455             self._lastKey = key
#     456         elif cleared:
#
# c:\python27\arcgis10.4\lib\site-packages\matplotlib\backends\backend_agg.pyc in __init__(self, width, height, dpi)
#      99         self.width = width
#     100         self.height = height
# --> 101         self._renderer = _RendererAgg(int(width), int(height), dpi)
#     102         self._filter_renderers = []
#     103
#
# MemoryError: In RendererAgg: Out of memory

# %%
# Question #3
import pandas as pd
import csv
import matplotlib.pyplot as plt
import numpy as np
data = pd.DataFrame.from_csv("UIUC-iSchool-DataViz/fall2018/week02/data/la-county-restaurant-inspections.csv")
city_count = 0
data_csv = open('UIUC-iSchool-DataViz/fall2018/week02/data/la-county-restaurant-inspections.csv')
csv_reader = csv.reader(data_csv)
header = next(csv_reader)
for line in csv_reader:
    city = line[3]
    if city == "LANCASTER":
        city_count += 1
print 'Facilities in the city of Lancaster were visited', str(city_count), 'times.'
##Visualization
data['facility_city'].value_counts().plot(kind='bar')
## This is categorical data, but may seem to be continuous as well because cities are also different and varies across the dataset.
## However since it has even less duplicates I also used it to filter the data.
# Out:
# Facilities in the city of Lancaster were visited 2371 times.

# %%
# Question #4
import pandas as pd
from decimal import *
import csv
import matplotlib.pyplot as plt
import numpy as np
data = pd.DataFrame.from_csv("UIUC-iSchool-DataViz/fall2018/week02/data/la-county-restaurant-inspections.csv")
emp_count = 0
total_count = 0
data_csv = open('UIUC-iSchool-DataViz/fall2018/week02/data/la-county-restaurant-inspections.csv')
csv_reader = csv.reader(data_csv)
header = next(csv_reader)
for line in csv_reader:
    employee = line[1]
    total_count += 1
    if employee == "EE0000145":
        emp_count += 1
getcontext().prec = 2
print 'Employee EE0000145 visited facilities', Decimal(emp_count)/Decimal(total_count) * 100, '% of times.'
##Visualization
data['employee_id'].value_counts().plot(kind='pie')
## This is a strong categorical data because ID was used for filtering. Each ID represent employees (is not large variety) that can be used as a separate category.
# Out:
# Employee EE0000145 visited facilities 0.58 % of times.

# %%
# Question #5
from decimal import *
import pandas as pd
import csv
import matplotlib.pyplot as plt
import numpy as np
data = pd.DataFrame.from_csv("UIUC-iSchool-DataViz/fall2018/week02/data/la-county-restaurant-inspections.csv")
fac_count = 0
total_count = 0
data_csv = open('UIUC-iSchool-DataViz/fall2018/week02/data/la-county-restaurant-inspections.csv')
csv_reader = csv.reader(data_csv)
header = next(csv_reader)
for line in csv_reader:
    facility = line[4]
    total_count += 1
    if facility == "FA0013858":
        fac_count += 1
getcontext().prec = 2
print 'Facility FA0013858 was visited', Decimal(fac_count)/Decimal(total_count) * 100, '% of times.' 
##Visualization
data['facility_id'].value_counts().plot(kind='pie')
## This is a strong categorical data because each facility has an ID number.
# Out:
# Facility FA0013858 was visited 0.0099 % of times.

# %%
# Question #6
import pandas as pd
from decimal import *
import csv
import matplotlib.pyplot as plt
import numpy as np
emp_city_count = 0
total_count = 0
data_csv = open('UIUC-iSchool-DataViz/fall2018/week02/data/la-county-restaurant-inspections.csv')
csv_reader = csv.reader(data_csv)
header = next(csv_reader)
for line in csv_reader:
    employee_2 = line[1]
    city_2 = line[3]
    if employee_2 == "EE0000593":
        total_count += 1
        if city_2 == "GRANADA HILLS": 
            emp_city_count += 1 
getcontext().prec = 3
print 'Facilities in the city of Granada Hills were visited by employee EE0000593', Decimal(emp_city_count)/Decimal(total_count) * 100, '% of times.'
##Visualization
plt.plot(emp_city_count, total_count)      
##This is a strong categorical data because two filterings were used, filtering by city, and employee.
# Out:
# Facilities in the city of Granada Hills were visited by employee EE0000593 60.2 % of times.
